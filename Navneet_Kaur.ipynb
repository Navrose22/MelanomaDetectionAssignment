# %% [markdown]
# <a href="https://colab.research.google.com/github/Navrose22/MelanomaDetectionAssignment/blob/main/Navneet_Kaur.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MELANOMA DETECTION ASSIGNMENT**

# %% [markdown]
# **Problem statement**: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution that can evaluate images and alert dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ## Importing Skin Cancer Data

# %%
# Importing all the necessary libraries
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !unzip /content/gdrive/MyDrive/load_data/CNN_assignment.zip -d /content/gdrive/MyDrive/load_data/CNN_Assignment
# Out:
# Archive:  /content/gdrive/MyDrive/load_data/CNN_assignment.zip
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0010512.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0010889.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024468.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024470.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024511.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024646.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024654.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024707.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024763.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024771.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024800.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024913.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024948.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0025368.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0025427.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0025605.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024331.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024332.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024345.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024360.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024403.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024411.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024431.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024432.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024436.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024443.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024448.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024452.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024454.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024457.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024461.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024472.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0001114.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0001130.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0011410.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0011433.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0011478.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0011677.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0011865.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0024318.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0024330.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0024386.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0024396.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0024553.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0024845.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0024973.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0024994.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0025154.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/melanoma/ISIC_0000002.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/melanoma/ISIC_0000004.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/melanoma/ISIC_0000013.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/melanoma/ISIC_0000022.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/melanoma/ISIC_0000026.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/melanoma/ISIC_0000029.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/melanoma/ISIC_0000030.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/melanoma/ISIC_0000031.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/melanoma/ISIC_0000035.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/melanoma/ISIC_0000036.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/melanoma/ISIC_0000040.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/melanoma/ISIC_0000043.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/melanoma/ISIC_0000046.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/melanoma/ISIC_0000049.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/melanoma/ISIC_0000054.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/melanoma/ISIC_0000056.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/nevus/ISIC_0000000.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/nevus/ISIC_0000001.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/nevus/ISIC_0000003.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/nevus/ISIC_0000005.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/nevus/ISIC_0000006.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/nevus/ISIC_0000007.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/nevus/ISIC_0000008.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/nevus/ISIC_0000009.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/nevus/ISIC_0000010.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/nevus/ISIC_0000011.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/nevus/ISIC_0000012.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/nevus/ISIC_0000014.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/nevus/ISIC_0000015.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/nevus/ISIC_0000016.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/nevus/ISIC_0000017.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/nevus/ISIC_0000018.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/pigmented benign keratosis/ISIC_0024312.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/pigmented benign keratosis/ISIC_0024324.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/pigmented benign keratosis/ISIC_0024336.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/pigmented benign keratosis/ISIC_0024337.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/pigmented benign keratosis/ISIC_0024338.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/pigmented benign keratosis/ISIC_0024358.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/pigmented benign keratosis/ISIC_0024371.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/pigmented benign keratosis/ISIC_0024381.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/pigmented benign keratosis/ISIC_0024382.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/pigmented benign keratosis/ISIC_0024383.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/pigmented benign keratosis/ISIC_0024408.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/pigmented benign keratosis/ISIC_0024409.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/pigmented benign keratosis/ISIC_0024412.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/pigmented benign keratosis/ISIC_0024420.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/pigmented benign keratosis/ISIC_0024422.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/pigmented benign keratosis/ISIC_0024426.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/seborrheic keratosis/ISIC_0010803.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/seborrheic keratosis/ISIC_0010808.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/seborrheic keratosis/ISIC_0010809.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/squamous cell carcinoma/ISIC_0011593.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/squamous cell carcinoma/ISIC_0011726.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/squamous cell carcinoma/ISIC_0011750.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/squamous cell carcinoma/ISIC_0011751.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/squamous cell carcinoma/ISIC_0012079.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/squamous cell carcinoma/ISIC_0024329.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/squamous cell carcinoma/ISIC_0024372.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/squamous cell carcinoma/ISIC_0024418.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/squamous cell carcinoma/ISIC_0024450.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/squamous cell carcinoma/ISIC_0024463.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/squamous cell carcinoma/ISIC_0024517.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/squamous cell carcinoma/ISIC_0024522.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/squamous cell carcinoma/ISIC_0024539.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/squamous cell carcinoma/ISIC_0024562.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/squamous cell carcinoma/ISIC_0024575.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/squamous cell carcinoma/ISIC_0024579.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/vascular lesion/ISIC_0024370.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/vascular lesion/ISIC_0024375.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/vascular lesion/ISIC_0024402.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0025780.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0025803.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0025825.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0025953.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0025957.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0025992.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026040.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026149.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026171.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026194.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026212.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026457.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026468.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026525.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026575.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026625.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026626.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026650.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026702.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026709.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026729.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026765.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026848.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026857.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026905.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026984.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027172.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027254.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027334.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027447.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027452.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027536.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027562.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027580.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027615.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027650.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027668.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027802.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027829.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027884.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027896.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027950.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027958.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0028063.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0028076.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0028190.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0028314.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0028370.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0028393.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0028517.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0028558.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0028820.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0028854.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0028941.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0028990.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029025.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029041.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029133.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029141.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029210.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029309.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029460.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029500.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029659.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029713.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029781.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029827.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029830.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029840.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029900.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029915.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029930.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0030036.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0030133.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0030142.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0030143.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0030242.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0030344.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0030408.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0030463.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0030491.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0030586.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0030655.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0030730.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0030825.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0030826.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0030877.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0031040.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0031108.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0031228.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0031292.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0031335.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0031381.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0031430.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0031506.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0031609.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0031823.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0031922.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0031993.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0032135.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0032199.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0032206.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0032404.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0032422.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0032437.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0032854.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0033151.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0033358.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0033413.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0033456.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0033494.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0033705.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0033811.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0033866.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024504.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024515.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024550.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024564.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024572.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024573.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024582.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024590.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024595.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024632.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024634.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024665.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024666.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024673.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024743.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024787.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024795.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024799.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024829.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024833.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024848.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024885.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024897.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024931.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024949.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024984.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025019.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025031.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025046.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025102.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025144.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025260.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025266.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025285.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025299.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025301.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025322.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025362.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025383.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025417.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025433.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025467.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025509.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025513.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025530.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025557.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025576.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025601.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025617.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025630.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025644.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025650.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025691.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025700.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025711.jpg
# ...
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0027522.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0027563.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0027665.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0027672.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0027790.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0027856.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0027888.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0027903.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0027937.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0027983.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0028146.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0028163.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0028188.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0028406.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0028431.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0028680.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0028714.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0028885.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0029099.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0029404.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0029439.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0029448.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0029486.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0029514.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0029608.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0029742.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0029877.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0029889.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0030070.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0030104.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0030275.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0030283.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0030606.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0030722.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0030770.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0030882.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0030956.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031065.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031090.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031093.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031103.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031197.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031201.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031215.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031217.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031270.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031276.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031346.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031648.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031706.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031719.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031759.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031901.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031950.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031955.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031996.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032057.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032076.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032240.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032270.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032409.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032538.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032545.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032557.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032614.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032692.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032715.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032745.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032775.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032839.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032866.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032867.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032890.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032919.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032932.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033031.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033092.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033123.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033135.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033158.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033230.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033254.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033349.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033450.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033458.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033565.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033591.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033608.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033749.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033762.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033817.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033844.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033969.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033991.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0034196.jpg
#   inflating: /content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0034214.jpg

# %%
# Defining the path for train and test images
data_train = pathlib.Path("/content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
data_test = pathlib.Path('/content/gdrive/MyDrive/load_data/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test')

# %%
image_count_train = len(list(data_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ## Keras pre-processing.
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# # Create a dataset
# Let's define some parameters for the loader

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
## Preparaing Train Dataset
## Using seed=123
train_data_set = tf.keras.preprocessing.image_dataset_from_directory( data_train, seed=123, validation_split = 0.2,
            subset = 'training', image_size=(img_height, img_width), batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Preparaing Validation Dataset
val_data_set = tf.keras.preprocessing.image_dataset_from_directory(data_train, seed=123,validation_split = 0.2,
         subset = 'validation', image_size=(img_height, img_width), batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# Printing class names of train data set
class_names = train_data_set.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %%
# Checking type of train data set
print(type(train_data_set))
# Out:
# <class 'tensorflow.python.data.ops.prefetch_op._PrefetchDataset'>

# %%
# Let's print images with their respective labels
for images, labels in train_data_set.take(1):
  print(len(images))
  print(len(labels))
# Out:
# 32
# 32

# %%
# Visualizing single instance of the image
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 10))
for images, labels in train_data_set.take(1):
  print(len(images))
  print(len(labels))
  plt.imshow(images[10].numpy().astype("uint8"))
  plt.title(class_names[labels[10]])
  plt.axis("off")
# Out:
# 32
# 32

# %% [markdown]
# # Visualize the data

# %%
# Visualizing one instance of all the nine classes present in the train dataset
plt.figure(figsize=(10, 10))
for images, labels in train_data_set.take(5):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
# Visualizing one instance of all the nine classes present in the validation dataset
plt.figure(figsize=(10, 10))
for images, labels in val_data_set.take(5):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
print(type(train_data_set))
print(len(train_data_set))
# Out:
# <class 'tensorflow.python.data.ops.prefetch_op._PrefetchDataset'>
# 56

# %% [markdown]
# A tensor with the shape (32, 180, 180, 3) is the image_batch. This is a set of 32 images of shape (180x180x3), where the final dimension is the RGB colour channels. The labels for the 32 images correspond to the label_batch, which is a tensor of the shape (32,).

# %% [markdown]
# Dataset.cache() keeps the images in memory after they're loaded off disk during the first epoch.
#
# Dataset.prefetch() overlaps data preprocessing and model execution while training.

# %%
#overlaps data preprocessing and model execution while training., Speed up training
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_data_set = train_data_set.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_data_set = val_data_set.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # Creating the Model

# %% [markdown]
# A tensor with the shape (32, 180, 180, 3) is the image_batch. This is a set of 32 (180x180x3) images, where the final dimension is
# the RGB colour channels. The labels for the 32 images correspond to the label_batch, which is a tensor of the shape (32,).

# %%
# Total classes
num_classes = 9

#A Sequential model is appropriate for a plain stack of layers where each layer has exactly one input tensor and one output tensor
model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),

  # 2D convolution layer (e.g. spatial convolution over images).
  layers.Conv2D(16, 3, padding='same', activation='relu'),

  # We slide over the feature map and extract tiles of a specified size.
  # Downsamples the input along its spatial dimensions (height and width) by taking the maximum value over an input window (of size defined by pool_size) for each channel of the input.
  layers.MaxPooling2D(),

  # We slide over the feature map and extract tiles of a specified size.
  layers.Conv2D(32, 3, padding='same', activation='relu'),

  layers.MaxPooling2D(),

  layers.Conv2D(64, 3, padding='same', activation='relu'),

  # We slide over the feature map and extract tiles of a specified size.
  # Advantages of downsampling - Decreased size of input for upcoming layers, Works against overfitting
  layers.MaxPooling2D(),

  # Flattening - Convert into 1D feature vector.  Flattens all its structure to create a single long feature vector
  ## Flattens the input. Does not affect the batch size.
  layers.Flatten(),

  # fully connected layer
  # A hidden layer in which each node is connected to every node in the subsequent hidden layer.
  # A fully connected layer is also known as a dense layer.

  layers.Dense(128, activation='relu'),

  # Dense is the only actual network layer in that model. A Dense layer feeds all outputs from the previous layer to all its neurons, each neuron providing one output to the next layer.
  # It's the most basic layer in neural networks. A Dense(10) has ten neurons. A Dense(512) has 512 neurons.
  # Dense implements the operation: output = activation(dot(input, kernel)
  # Dense Layer - A dense layer represents a matrix vector multiplication.  each input node is connected to each output node.
  layers.Dense(num_classes)
  # Dense Layer - A dense layer represents a matrix vector multiplication.  each input node is connected to each output node.
])

# %% [markdown]
# ## Compiling the model

# %%
# Let's view the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 90, 90, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 45, 45, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 22, 22, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dense_1 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 3989801 (15.22 MB)
# Trainable params: 3989801 (15.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
# Let's fit the model using '20' epochs
epochs = 20
history = model.fit(train_data_set, validation_data=val_data_set, epochs=epochs)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 104s 2s/step - loss: 1.9718 - accuracy: 0.2595 - val_loss: 2.0253 - val_accuracy: 0.2192
# Epoch 2/20
# 56/56 [==============================] - 67s 1s/step - loss: 1.6929 - accuracy: 0.3733 - val_loss: 1.5281 - val_accuracy: 0.4474
# Epoch 3/20
# 56/56 [==============================] - 67s 1s/step - loss: 1.4466 - accuracy: 0.4983 - val_loss: 1.4666 - val_accuracy: 0.4810
# Epoch 4/20
# 56/56 [==============================] - 66s 1s/step - loss: 1.3320 - accuracy: 0.5508 - val_loss: 1.4390 - val_accuracy: 0.5235
# Epoch 5/20
# 56/56 [==============================] - 70s 1s/step - loss: 1.2444 - accuracy: 0.5597 - val_loss: 1.4027 - val_accuracy: 0.5056
# Epoch 6/20
# 56/56 [==============================] - 65s 1s/step - loss: 1.1366 - accuracy: 0.5982 - val_loss: 1.4309 - val_accuracy: 0.5235
# Epoch 7/20
# 56/56 [==============================] - 67s 1s/step - loss: 1.0291 - accuracy: 0.6345 - val_loss: 1.3856 - val_accuracy: 0.5548
# Epoch 8/20
# 56/56 [==============================] - 67s 1s/step - loss: 0.9656 - accuracy: 0.6479 - val_loss: 1.3746 - val_accuracy: 0.5347
# Epoch 9/20
# 56/56 [==============================] - 67s 1s/step - loss: 0.8814 - accuracy: 0.6836 - val_loss: 1.5013 - val_accuracy: 0.5078
# Epoch 10/20
# 56/56 [==============================] - 67s 1s/step - loss: 0.8397 - accuracy: 0.6914 - val_loss: 1.5725 - val_accuracy: 0.5056
# Epoch 11/20
# 56/56 [==============================] - 66s 1s/step - loss: 0.6863 - accuracy: 0.7584 - val_loss: 1.5655 - val_accuracy: 0.5436
# Epoch 12/20
# 56/56 [==============================] - 68s 1s/step - loss: 0.6034 - accuracy: 0.7679 - val_loss: 1.8087 - val_accuracy: 0.5213
# Epoch 13/20
# 56/56 [==============================] - 69s 1s/step - loss: 0.4891 - accuracy: 0.8253 - val_loss: 1.9185 - val_accuracy: 0.5391
# Epoch 14/20
# 56/56 [==============================] - 67s 1s/step - loss: 0.4468 - accuracy: 0.8304 - val_loss: 1.7963 - val_accuracy: 0.5257
# Epoch 15/20
# 56/56 [==============================] - 70s 1s/step - loss: 0.3769 - accuracy: 0.8610 - val_loss: 1.9465 - val_accuracy: 0.5526
# Epoch 16/20
# 56/56 [==============================] - 66s 1s/step - loss: 0.3903 - accuracy: 0.8555 - val_loss: 1.8535 - val_accuracy: 0.5436
# Epoch 17/20
# 56/56 [==============================] - 66s 1s/step - loss: 0.3248 - accuracy: 0.8817 - val_loss: 1.8735 - val_accuracy: 0.5548
# Epoch 18/20
# 56/56 [==============================] - 66s 1s/step - loss: 0.3088 - accuracy: 0.8834 - val_loss: 2.4210 - val_accuracy: 0.5302
# Epoch 19/20
# 56/56 [==============================] - 67s 1s/step - loss: 0.2489 - accuracy: 0.9141 - val_loss: 2.3009 - val_accuracy: 0.5705
# Epoch 20/20
# 56/56 [==============================] - 66s 1s/step - loss: 0.2493 - accuracy: 0.9029 - val_loss: 2.1668 - val_accuracy: 0.5391

# %% [markdown]
# ## Training the model

# %%
# Train the model
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
num_classes = 9

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  #We slide over the feature map and extract tiles of a specified size.
  layers.MaxPooling2D(),
  layers.Conv2D(128, 3, padding='same', activation='relu'),
  #We slide over the feature map and extract tiles of a specified size.
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  #We slide over the feature map and extract tiles of a specified size.
  layers.MaxPooling2D(),
  #Advantages of downsampling - Decreased size of input for upcoming layers, Works against overfitting
  layers.Flatten(),
  #Flattening - Convert into 1D feature vector.  Flattens all its structure to create a single long feature vector
  layers.Dense(128, activation='relu'),
  #Dense Layer - A dense layer represents a matrix vector multiplication.  each input node is connected to each output node.
  layers.Dense(num_classes)
  #Dense Layer - A dense layer represents a matrix vector multiplication.  each input node is connected to each output node.
])

# %% [markdown]
# Findings from the above observation:
#
#
# *   The model is overfitting because there is difference in loss
#      functions in training & test.
# *   The accuracy is just around low because there are enough features to
#      remember the pattern.
# *   Besides this, it is hard to find wheather the model overfit or underfit.
#
# Let's do some data augmentation to find more accuracy.

# %% [markdown]
# # Visualizing training results

# %% [markdown]
# Data augmentation: Data augmentation can address a variety of challenges when training a CNN model, such as limited or imbalanced data, overfitting, and variation and complexity. This technique can increase the size of the dataset and balance the classes by applying different transformations.

# %%
# Lets see the distribution of augmented data after adding new images to the original training data.
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", input_shape=(img_height,
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
    layers.experimental.preprocessing.RandomTranslation(1,.5,fill_mode="reflect",interpolation="bilinear",seed=None,fill_value=0.0),
    layers.experimental.preprocessing.RandomCrop(img_height,img_width),
  ]
)

# %%
# Visualizing the augmentation strategy for one instance of image
plt.figure(figsize=(10, 10))
for images, _ in train_data_set.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# ## Creating the model, compiling and training  the model

# %%
# Creating the model
# Using dropout as we some evidences of overfitting.
model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(128, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(256, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
# Compiling the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# Training the model
epochs = 20
history = model.fit(train_data_set,
  validation_data=val_data_set,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 449s 8s/step - loss: 2.3032 - accuracy: 0.1886 - val_loss: 1.9455 - val_accuracy: 0.2729
# Epoch 2/20
# 56/56 [==============================] - 459s 8s/step - loss: 1.8367 - accuracy: 0.3281 - val_loss: 1.6830 - val_accuracy: 0.3893
# Epoch 3/20
# 56/56 [==============================] - 462s 8s/step - loss: 1.6913 - accuracy: 0.3733 - val_loss: 1.5910 - val_accuracy: 0.4072
# Epoch 4/20
# 56/56 [==============================] - 480s 9s/step - loss: 1.6541 - accuracy: 0.3733 - val_loss: 1.6032 - val_accuracy: 0.3758
# Epoch 5/20
# 56/56 [==============================] - 454s 8s/step - loss: 1.6190 - accuracy: 0.3962 - val_loss: 1.8377 - val_accuracy: 0.3579
# Epoch 6/20
# 56/56 [==============================] - 454s 8s/step - loss: 1.6502 - accuracy: 0.3962 - val_loss: 1.5705 - val_accuracy: 0.4027
# Epoch 7/20
# 56/56 [==============================] - 441s 8s/step - loss: 1.5686 - accuracy: 0.4107 - val_loss: 1.5547 - val_accuracy: 0.4004
# Epoch 8/20
# 56/56 [==============================] - 452s 8s/step - loss: 1.5311 - accuracy: 0.4208 - val_loss: 1.6117 - val_accuracy: 0.4004
# Epoch 9/20
# 56/56 [==============================] - 448s 8s/step - loss: 1.5358 - accuracy: 0.4297 - val_loss: 1.6633 - val_accuracy: 0.4251
# Epoch 10/20
# 56/56 [==============================] - 436s 8s/step - loss: 1.5036 - accuracy: 0.4291 - val_loss: 1.6300 - val_accuracy: 0.4541
# Epoch 11/20
# 56/56 [==============================] - 435s 8s/step - loss: 1.4979 - accuracy: 0.4459 - val_loss: 1.5432 - val_accuracy: 0.4273
# Epoch 12/20
# 56/56 [==============================] - 435s 8s/step - loss: 1.5186 - accuracy: 0.4531 - val_loss: 1.4479 - val_accuracy: 0.4899
# Epoch 13/20
# 56/56 [==============================] - 448s 8s/step - loss: 1.4834 - accuracy: 0.4587 - val_loss: 1.4984 - val_accuracy: 0.4430
# Epoch 14/20
# 56/56 [==============================] - 448s 8s/step - loss: 1.4814 - accuracy: 0.4576 - val_loss: 1.5299 - val_accuracy: 0.4452
# Epoch 15/20
# 56/56 [==============================] - 499s 9s/step - loss: 1.4528 - accuracy: 0.4693 - val_loss: 1.5311 - val_accuracy: 0.4631
# Epoch 16/20
# 56/56 [==============================] - 459s 8s/step - loss: 1.4013 - accuracy: 0.4900 - val_loss: 1.5208 - val_accuracy: 0.4698
# Epoch 17/20
# 56/56 [==============================] - 448s 8s/step - loss: 1.3984 - accuracy: 0.4967 - val_loss: 1.5151 - val_accuracy: 0.4877
# Epoch 18/20
# 56/56 [==============================] - 481s 9s/step - loss: 1.4070 - accuracy: 0.4955 - val_loss: 1.5030 - val_accuracy: 0.4519
# Epoch 19/20
# 18/56 [========>.....................] - ETA: 4:44 - loss: 1.4886 - accuracy: 0.4392

# %%
# Visualizing the results
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# Building CNN with TensorFlow
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Setting batch size and image size
batch_size = 100
IMG_SHAPE = 224

# Create training images generator
#Generate batches of tensor image data with real-time data augmentation.
#https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator
image_gen_train = ImageDataGenerator(
                    rescale=1./255,
                    rotation_range=45,
                    width_shift_range=.15,
                    height_shift_range=.15,
                    horizontal_flip=True,
                    zoom_range=0.5
                    )
#https://keras.io/api/preprocessing/image/
#Then calling image_dataset_from_directory(main_directory, labels='inferred') will return a tf.data.Dataset that yields batches of images from the subdirectories
train_data_gen = image_gen_train.flow_from_directory(
                                                batch_size=batch_size,
                                                directory=train_data_set,
                                                shuffle=True,
                                                target_size=(IMG_SHAPE,IMG_SHAPE),
                                                class_mode='sparse'
                                                )

# Create validation images generator
image_gen_val = ImageDataGenerator(rescale=1./255)
val_data_gen = image_gen_val.flow_from_directory(batch_size=batch_size,
                                                 directory=val_data_set,
                                                 target_size=(IMG_SHAPE, IMG_SHAPE),
                                                 class_mode='sparse')

# %%
#Creating a CNN model
#Experiment #1
#A Sequential model is appropriate for a plain stack of layers where each layer has exactly one input tensor and one output tensor
import numpy as np
import glob
import shutil
import matplotlib.pyplot as plt

# Importing layers explicitly to keep our code compact
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D


model = Sequential()

#2D convolution layer (e.g. spatial convolution over images).
model.add(Conv2D(16, 3, padding='same', activation='relu', input_shape=(IMG_SHAPE,IMG_SHAPE, 3)))
#Downsamples the input along its spatial dimensions (height and width) by taking the maximum value over an input window (of size defined by pool_size) for each channel of the input.
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, 3, padding='same', activation='relu'))

#Downsamples the input along its spatial dimensions (height and width) by taking the maximum value over an input window (of size defined by pool_size) for each channel of the input.
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, 3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

#Flattens the input. Does not affect the batch size.
model.add(Flatten())

#https://keras.io/api/layers/regularization_layers/dropout/
#The Dropout layer randomly sets input units to 0 with a frequency of rate at each step during training time, which helps prevent overfitting. Inputs not set to 0 are scaled up by 1/(1 - rate) such that the sum over all inputs is unchanged
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))

model.add(Dropout(0.2))

#Just your regular densely-connected NN layer.
#Dense is the only actual network layer in that model. A Dense layer feeds all outputs from the previous layer to all its neurons, each neuron providing one output to the next layer.
#It's the most basic layer in neural networks. A Dense(10) has ten neurons. A Dense(512) has 512 neurons.
#Dense implements the operation: output = activation(dot(input, kernel)
model.add(Dense(9))

# Compile the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# Train the model
epochs = 20

history = model.fit(
  train_data_gen,
  validation_data=val_data_gen,
  epochs=10
)

# %%
import matplotlib.pyplot as plt
epochs=10
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)



plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
dataframe_dict_original = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
original_df

# %%
from sklearn.preprocessing import LabelEncoder
from collections import Counter
# split into input and output elements
X, y = original_df['Path'], original_df['Label']
# label encode the target variable
y = LabelEncoder().fit_transform(y)
# summarize distribution
counter = Counter(y)
for k,v in counter.items():
	per = v / len(y) * 100
	print('Class=%d, n=%d (%.3f%%)' % (k, v, per))
# plot the distribution
plt.bar(counter.keys(), counter.values())
plt.show()

# %% [markdown]
# To use Augmentor, the following general procedure is followed:
#
# Instantiate a Pipeline object pointing to a directory containing your initial image data set.
# Define a number of operations to perform on this data set using your Pipeline object.
# Execute these operations by calling the Pipeline’s sample() method.

# %%
# !pip install Augmentor

# %%
#https://github.com/mdbloice/Augmentor
#https://github.com/mdbloice/Augmentor
datapath = r'/content/gdrive/MyDrive/upgrad/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis'
import Augmentor
p = Augmentor.Pipeline(datapath)
#Every function requires you to specify a probability, which is used to decide if an operation is applied to an image as it is passed through the augmentation pipeline.
p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
p.zoom(probability=0.5, min_factor=1.1, max_factor=1.5)
p.sample(150)
p.process()

# %%
path_to_training_dataset="/content/gdrive/MyDrive/SC/Train//"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path("/content/gdrive/MyDrive/upgrad/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
data_dir_test = pathlib.Path('/content/gdrive/MyDrive/upgrad/CNN_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)

# %% [markdown]
# Distribution of augmented data after adding new images to the original training data.

# %%
path_list_new = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
path_list_new

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new

# %%
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = original_df.append(df2)

# %%
new_df['Label'].value_counts()

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# # Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# # Create a training dataset

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training', ## Todo choose the correct parameter value, so that only training data is refered to
  image_size=(img_height, img_width),
  batch_size=batch_size)

# %% [markdown]
# # Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',## Todo choose the correct parameter value, so that only validation data is refered to,
  image_size=(img_height, img_width),
  batch_size=batch_size)

# %% [markdown]
#  **Normalization Model**

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
# Compiling model using optimizer and loss function appropriately
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# Training model
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)

# %%
# Visualizing the model results
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
